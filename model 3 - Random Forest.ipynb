# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already satisfied: sklearn in c:\users\lites\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\lites\anaconda3\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\lites\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\lites\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lites\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\lites\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.20.1)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\lites\anaconda3\lib\site-packages (1.0.1)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    6991 non-null   object
#  1   koi_fpflag_nt      6991 non-null   int64
#  2   koi_fpflag_ss      6991 non-null   int64
#  3   koi_fpflag_co      6991 non-null   int64
#  4   koi_fpflag_ec      6991 non-null   int64
#  5   koi_period         6991 non-null   float64
#  6   koi_period_err1    6991 non-null   float64
#  7   koi_period_err2    6991 non-null   float64
#  8   koi_time0bk        6991 non-null   float64
#  9   koi_time0bk_err1   6991 non-null   float64
#  10  koi_time0bk_err2   6991 non-null   float64
#  11  koi_impact         6991 non-null   float64
#  12  koi_impact_err1    6991 non-null   float64
#  13  koi_impact_err2    6991 non-null   float64
#  14  koi_duration       6991 non-null   float64
#  15  koi_duration_err1  6991 non-null   float64
#  16  koi_duration_err2  6991 non-null   float64
#  17  koi_depth          6991 non-null   float64
#  18  koi_depth_err1     6991 non-null   float64
#  19  koi_depth_err2     6991 non-null   float64
#  20  koi_prad           6991 non-null   float64
#  21  koi_prad_err1      6991 non-null   float64
#  22  koi_prad_err2      6991 non-null   float64
#  23  koi_teq            6991 non-null   int64
#  24  koi_insol          6991 non-null   float64
#  25  koi_insol_err1     6991 non-null   float64
#  26  koi_insol_err2     6991 non-null   float64
#  27  koi_model_snr      6991 non-null   float64
#  28  koi_tce_plnt_num   6991 non-null   int64
#  29  koi_steff          6991 non-null   int64
#  30  koi_steff_err1     6991 non-null   int64
#  31  koi_steff_err2     6991 non-null   int64
#  32  koi_slogg          6991 non-null   float64
#  33  koi_slogg_err1     6991 non-null   float64
#  34  koi_slogg_err2     6991 non-null   float64
#  35  koi_srad           6991 non-null   float64
#  36  koi_srad_err1      6991 non-null   float64
#  37  koi_srad_err2      6991 non-null   float64
#  38  ra                 6991 non-null   float64
#  39  dec                6991 non-null   float64
#  40  koi_kepmag         6991 non-null   float64
# dtypes: float64(31), int64(9), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt','koi_fpflag_ss','koi_fpflag_co','koi_fpflag_ec',
                        'koi_period','koi_period_err1','koi_period_err2',
                        'koi_time0bk','koi_time0bk_err1','koi_time0bk_err2',
                        'koi_impact','koi_impact_err1','koi_impact_err2',
                        'koi_duration','koi_duration_err1','koi_duration_err2',
                        'koi_depth','koi_depth_err1','koi_depth_err2',
                        'koi_prad','koi_prad_err1','koi_prad_err2',
                        'koi_teq','koi_insol','koi_insol_err1','koi_insol_err2',
                        'koi_model_snr','koi_steff','koi_steff_err1','koi_steff_err2',
                        'koi_slogg','koi_slogg_err1','koi_slogg_err2',
                        'koi_srad','koi_srad_err1','koi_srad_err2',
                        'ra','dec','koi_kepmag']]
selected_features.head(20)
# Out:
#     koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0               0              0              0              0   54.418383
# 1               0              1              0              0   19.899140
# 2               0              1              0              0    1.736952
# 3               0              0              0              0    2.525592
# 4               0              0              0              0    4.134435
# 5               0              0              0              0    2.566589
# 6               0              0              0              0   16.068647
# 7               0              0              0              0    2.470613
# 8               0              1              0              0    2.204735
# 9               0              0              0              0    3.522498
# 10              0              0              0              0    3.709214
# 11              0              1              0              0   11.521446
# 12              0              1              0              0   19.221389
# 13              0              1              0              0   16.469838
# 14              0              0              0              0    9.273582
# 15              0              0              0              0    6.029303
# 16              0              1              1              1    2.696371
# 17              0              0              0              0    3.941052
# 18              0              1              0              0  386.603053
# 19              0              0              0              0   21.676992
#
#     koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0      2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1      1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2      2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3      3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4      1.050000e-05    -1.050000e-05   172.979370          0.001900
# 5      1.780000e-05    -1.780000e-05   179.554370          0.004610
# 6      1.090000e-05    -1.090000e-05   173.621937          0.000517
# 7      2.700000e-08    -2.700000e-08   122.763305          0.000009
# 8      4.300000e-08    -4.300000e-08   121.358542          0.000016
# 9      1.980000e-07    -1.980000e-07   121.119423          0.000047
# 10     6.540000e-06    -6.540000e-06   133.983180          0.001430
# 11     1.980000e-06    -1.980000e-06   170.839688          0.000131
# 12     1.120000e-06    -1.120000e-06   184.552164          0.000045
# 13     1.360000e-05    -1.360000e-05   180.881761          0.000623
# 14     1.040000e-05    -1.040000e-05   173.258155          0.000877
# 15     5.510000e-06    -5.510000e-06   171.602959          0.000713
# 16     7.530000e-06    -7.530000e-06   170.737690          0.002340
# 17     1.090000e-05    -1.090000e-05   136.086620          0.002330
# 18     1.369000e-04    -1.369000e-04   166.342079          0.000299
# 19     7.010000e-05    -7.010000e-05   171.535940          0.002580
#
#     koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          -0.003520  ...             -81      4.467           0.064
# 1          -0.000581  ...            -176      4.544           0.044
# 2          -0.000115  ...            -174      4.564           0.053
# 3          -0.001130  ...            -211      4.438           0.070
# 4          -0.001900  ...            -232      4.486           0.054
# 5          -0.004610  ...            -232      4.486           0.054
# 6          -0.000517  ...             -83      4.485           0.083
# 7          -0.000009  ...             -78      4.457           0.024
# 8          -0.000016  ...             -89      4.019           0.033
# 9          -0.000047  ...            -137      4.169           0.055
# 10         -0.001430  ...            -117      4.407           0.085
# 11         -0.000131  ...            -172      4.554           0.033
# 12         -0.000045  ...            -200      4.496           0.052
# 13         -0.000623  ...            -153      4.517           0.088
# 14         -0.000877  ...            -146      4.583           0.065
# 15         -0.000713  ...            -123      4.648           0.020
# 16         -0.002340  ...            -149      4.504           0.090
# 17         -0.002330  ...             -77      4.440           0.098
# 18         -0.000299  ...             -79      4.081           0.014
# 19         -0.002580  ...             -79      4.500           0.075
#
#     koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0           -0.096     0.927          0.105         -0.061  291.93423
# 1           -0.176     0.868          0.233         -0.078  297.00482
# 2           -0.168     0.791          0.201         -0.067  285.53461
# 3           -0.210     1.046          0.334         -0.133  288.75488
# 4           -0.229     0.972          0.315         -0.105  296.28613
# 5           -0.229     0.972          0.315         -0.105  296.28613
# 6           -0.028     0.848          0.033         -0.072  286.99948
# 7           -0.024     0.964          0.038         -0.038  286.80847
# 8           -0.027     1.952          0.099         -0.110  292.24728
# 9           -0.045     1.451          0.110         -0.110  281.28812
# 10          -0.114     1.022          0.143         -0.107  295.64871
# 11          -0.176     0.848          0.224         -0.075  297.07993
# 12          -0.208     0.947          0.308         -0.096  295.81454
# 13          -0.072     0.786          0.088         -0.088  297.15442
# 14          -0.035     0.696          0.056         -0.068  288.13824
# 15          -0.056     0.672          0.062         -0.036  283.71088
# 16          -0.060     0.819          0.067         -0.082  283.76547
# 17          -0.045     0.910          0.057         -0.086  292.37613
# 18          -0.014     1.580          0.064         -0.064  292.27374
# 19          -0.020     0.828          0.032         -0.065  290.46512
#
#           dec  koi_kepmag
# 0   48.141651      15.347
# 1   48.134129      15.436
# 2   48.285210      15.597
# 3   48.226200      15.509
# 4   48.224670      15.714
# 5   48.224670      15.714
# 6   48.375790      15.841
# 7   49.316399      11.338
# 8   47.969521      10.463
# 9   42.451080      13.563
# 10  48.495560      12.772
# 11  47.597401      15.472
# 12  47.690350      15.341
# 13  47.668701      15.788
# 14  47.724449      15.302
# 15  47.863270      15.784
# 16  47.804298      15.269
# 17  47.880989      15.416
# 18  37.671558      12.394
# 19  47.929180      15.377
#
# [20 rows x 39 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

label_encoder.fit(df["koi_disposition"])
label_encoder.classes_

y = label_encoder.transform(df["koi_disposition"])
y
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 5061              1              0              0              0  289.788624
# 2537              0              0              0              0   15.873610
# 985               0              0              0              0   15.274439
# 6025              0              0              0              0  381.979770
# 3779              1              0              0              0  361.526458
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 5061         0.007031        -0.007031    370.80390           0.02380
# 2537         0.000045        -0.000045    182.40408           0.00212
# 985          0.000040        -0.000040    147.57983           0.00209
# 6025         0.039820        -0.039820    163.18050           0.05110
# 3779         0.008157        -0.008157    339.33040           0.01340
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 5061          -0.02380  ...            -312      3.946           0.201
# 2537          -0.00212  ...            -187      4.607           0.036
# 985           -0.00209  ...             -69      4.091           0.018
# 6025          -0.05110  ...             -50      4.724           0.060
# 3779          -0.01340  ...            -316      4.064           0.170
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 5061          -0.220     2.407          0.835         -0.642  295.32828
# 2537          -0.135     0.737          0.162         -0.058  290.47134
# 985           -0.018     1.518          0.092         -0.061  294.21893
# 6025          -0.060     0.526          0.050         -0.050  288.96823
# 3779          -0.170     1.923          0.576         -0.471  295.23029
#
#             dec  koi_kepmag
# 5061  38.847500      10.924
# 2537  44.387081      13.766
# 985   49.479221      13.438
# 6025  44.448341      15.494
# 3779  42.516079      13.151
#
# [5 rows x 39 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %% [markdown]
# # Train the Model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=1)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
import numpy as np
np.array(y_test)
# Out:
# array([0, 2, 2, ..., 2, 0, 1])

# %%
# fit the data and make predictions
predictions = model.predict(X_test)

for x in range(0,5,1):
    print(f"Predictions: {predictions[x]}, Actual: {y_test[x]}")
# Out:
# Predictions: 1, Actual: 0
# Predictions: 2, Actual: 2
# Predictions: 2, Actual: 2
# Predictions: 1, Actual: 1
# Predictions: 0, Actual: 0

# %%
print(f"Training Data Score: {model.score(X_train_scaled, encoded_y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, encoded_y_test)}")
# Out:
# Training Data Score: 0.5554072096128171
# Testing Data Score: 0.5709382151029748

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(encoded_y_test, predictions,
                           target_names =["confirmed", "false positive", "candidate"]))
# Out:
#                 precision    recall  f1-score   support
#
#      confirmed       0.25      0.22      0.23       422
# false positive       0.29      0.28      0.29       450
#      candidate       0.51      0.55      0.53       876
#
#       accuracy                           0.40      1748
#      macro avg       0.35      0.35      0.35      1748
#   weighted avg       0.39      0.40      0.40      1748

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV

param_grid = { 
    'n_estimators': [200,500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [5,8,10],
    'criterion' :['gini', 'entropy']
}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# List the parameters
model.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200; total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200; total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200; total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200; total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200; total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500; total time=   2.5s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500; total time=   2.5s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500; total time=   2.5s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500; total time=   2.6s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500; total time=   2.8s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500; total time=   2.6s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500; total time=   2.6s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500; total time=   2.6s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500; total time=   2.7s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500; total time=   2.6s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200; total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200; total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200; total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200; total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=200; total time=   0.9s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=500; total time=   2.3s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=500; total time=   2.3s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=500; total time=   2.3s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=500; total time=   2.3s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=log2, n_estimators=500; total time=   2.3s
# [CV 1/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=200; total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=200; total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=200; total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=200; total time=   1.4s
# [CV 5/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=200; total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=500; total time=   3.7s
# [CV 2/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=500; total time=   3.7s
# [CV 3/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=500; total time=   3.7s
# [CV 4/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=500; total time=   3.8s
# [CV 5/5] END criterion=gini, max_depth=8, max_features=auto, n_estimators=500; total time=   3.7s
# [CV 1/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV 5/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500; total time=   3.7s
# [CV 2/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500; total time=   3.6s
# [CV 3/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500; total time=   3.7s
# [CV 4/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500; total time=   3.7s
# [CV 5/5] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500; total time=   3.7s
# [CV 1/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200; total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200; total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200; total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500; total time=   3.2s
# [CV 2/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500; total time=   3.2s
# [CV 3/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500; total time=   3.1s
# [CV 4/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500; total time=   3.1s
# [CV 5/5] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500; total time=   3.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=200; total time=   1.6s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=200; total time=   1.6s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=200; total time=   1.6s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=200; total time=   1.7s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=200; total time=   1.7s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=500; total time=   4.1s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=500; total time=   4.1s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=500; total time=   4.1s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=500; total time=   4.1s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=auto, n_estimators=500; total time=   4.1s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200; total time=   1.6s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200; total time=   1.6s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200; total time=   1.6s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200; total time=   1.5s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200; total time=   1.6s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500; total time=   4.1s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500; total time=   4.1s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500; total time=   4.1s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500; total time=   4.1s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500; total time=   4.1s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200; total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200; total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200; total time=   1.4s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200; total time=   1.5s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500; total time=   3.6s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500; total time=   3.5s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500; total time=   3.5s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500; total time=   3.5s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500; total time=   3.6s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200; total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200; total time=   1.5s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200; total time=   1.5s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200; total time=   1.5s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=200; total time=   1.6s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500; total time=   4.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500; total time=   4.0s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500; total time=   4.0s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500; total time=   4.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500; total time=   4.0s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.6s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.5s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.5s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.5s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=200; total time=   1.5s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500; total time=   4.0s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500; total time=   4.1s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500; total time=   3.9s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500; total time=   4.0s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500; total time=   4.1s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=200; total time=   1.3s
# [CV 1/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=500; total time=   3.5s
# [CV 2/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=500; total time=   3.4s
# [CV 3/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=500; total time=   3.4s
# [CV 4/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=500; total time=   3.4s
# [CV 5/5] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=500; total time=   3.5s
# [CV 1/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=200; total time=   2.2s
# [CV 2/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=200; total time=   2.1s
# [CV 3/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=200; total time=   2.1s
# [CV 4/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=200; total time=   2.2s
# [CV 5/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=200; total time=   2.2s
# [CV 1/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=500; total time=   5.6s
# [CV 2/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=500; total time=   5.7s
# [CV 3/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=500; total time=   5.7s
# [CV 4/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=500; total time=   5.6s
# [CV 5/5] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=500; total time=   5.5s
# [CV 1/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV 2/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV 3/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV 4/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV 5/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV 1/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500; total time=   5.7s
# [CV 2/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500; total time=   5.5s
# [CV 3/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500; total time=   5.6s
# [CV 4/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500; total time=   5.6s
# [CV 5/5] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500; total time=   5.7s
# [CV 1/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=200; total time=   1.8s
# [CV 2/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=200; total time=   1.9s
# [CV 3/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=200; total time=   1.9s
# [CV 4/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=200; total time=   1.9s
# [CV 5/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=200; total time=   1.9s
# [CV 1/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=500; total time=   4.9s
# [CV 2/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=500; total time=   5.0s
# [CV 3/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=500; total time=   5.0s
# [CV 4/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=500; total time=   4.9s
# [CV 5/5] END criterion=entropy, max_depth=8, max_features=log2, n_estimators=500; total time=   4.9s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=200; total time=   2.5s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=200; total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=200; total time=   2.5s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=200; total time=   2.6s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=200; total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500; total time=   6.4s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500; total time=   6.5s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500; total time=   6.4s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500; total time=   6.5s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500; total time=   6.5s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200; total time=   2.6s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200; total time=   2.5s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200; total time=   2.5s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200; total time=   2.5s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200; total time=   2.5s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500; total time=   6.5s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500; total time=   6.4s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500; total time=   6.4s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500; total time=   6.5s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500; total time=   6.4s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200; total time=   2.2s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200; total time=   2.1s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200; total time=   2.1s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200; total time=   2.2s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=200; total time=   2.2s
# [CV 1/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=500; total time=   5.5s
# [CV 2/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=500; total time=   5.7s
# [CV 3/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=500; total time=   5.6s
# [CV 4/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=500; total time=   5.4s
# [CV 5/5] END criterion=entropy, max_depth=10, max_features=log2, n_estimators=500; total time=   5.4s
# GridSearchCV(estimator=RandomForestClassifier(random_state=1),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 8, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-3d7817c5d645> in <module>
# ----> 1 print(grid.best_params_)
#       2 print(grid.best_score_)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bas
import joblib
filename = 'randomForestClassifier.sav'
joblib.dump(grid_rf, filename)
